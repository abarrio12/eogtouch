# %% [markdown]
# # Rellenado de muestras faltantes

# %%
import matplotlib.pyplot as plt
import pandas as pd

from routines import rellenar_muestras


df = pd.read_parquet("/Users/idertator/20250516_181320.parquet")

# %%
rellenadas = rellenar_muestras(df)

# %%
plt.plot(rellenadas["timestamp"], rellenadas["eyes_x"], label="X")
plt.plot(rellenadas["timestamp"], rellenadas["eyes_y"], label="Y")
plt.suptitle("Posicion Ojos")
plt.xlabel("Tiempo (ms)")
plt.ylabel("Posición (px)")
plt.legend()
plt.savefig("/Users/idertator/migraph.png")
